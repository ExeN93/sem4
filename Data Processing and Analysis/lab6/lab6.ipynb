# %% [markdown]
# Zad 1

# %% [markdown]
# Zad 2

# %% [markdown]
# 1. Liczymy średnią dla kolumn X
# 2. Odejmujemy średnia dla kolumn X od kolumn (B = X - X(średnia kolumn))
# 3. Liczymy macierz kowariancji m < b (np.cov)
# 4. Liczymy wartości własne dla wektora i macierzy (np.linalg.eig; scipy.linalg.eigh)
# 5. Sortujemy wartości własne wyżej wymienione malejąco (np.argsort)
# 6. Przycinamy do N [:n] [:, :n]
# 7. Rzutowanie R = B *(np.dot) M_WW(Wartość własna Macierzy)[:, :n]
#
# O = R * M_WW + X(średnia kolumn)
